# %%
import os
import numpy as np
from PIL import Image

# %%
path = '/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity'
dest_path = '/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity_img/'

# %%
files_path = [path+'/'+x for x in os.listdir(path)]

# %%
files_path
# Out:
# ['/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity/ZP7_Slice01115_x:0_y:0.npy',
#  '/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity/ZP9_Slice00457_x:1_y:0.npy',
#  '/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity/ZP4_Slice00720_x:0_y:1.npy',
#  '/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity/ZP9_Slice00595_x:1_y:1.npy',
#  '/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity/ZP4_Slice01009_x:1_y:0.npy',
#  '/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity/ZP3_Slice01213_x:1_y:2.npy',
#  '/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity/ZP1_Slice01130_x:1_y:0.npy',
#  '/home/jan/Documents/Trainingsdaten/datasets/Grid_size_874_binary/3layer/no_porosity/ZP5_Slice01027_x:0_y:0.npy',
# ...

# %%
for path in files_path:
    name = os.path.split(path)[1]
    array = np.load(path)
    img = Image.fromarray(array, 'RGB')
    img.save(dest_path+name[:-4]+'.png')
