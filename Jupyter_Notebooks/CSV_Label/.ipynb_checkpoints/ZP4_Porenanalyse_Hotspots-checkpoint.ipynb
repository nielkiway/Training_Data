# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/home/jan/Documents/Trainingsdaten/CT-Analyse_QualiPro_ZP_4/Porenanalyse_Porositäts-Hotspots_ZP4_17.12.2019.csv', delimiter =';')

# %%
data
# Out:
#     Position x [mm] Position y [mm] Position z [mm] Volumen [mm³]  \
# 0            3,3770         -0,2932         79,4013          0,00
# 1            3,3192         -0,0074         77,3140          0,06
# 2            3,2854          0,0072         59,8078          0,00
# 3            3,2752          0,0553         66,9683          0,04
# 4            3,2638          0,4990         67,0817          0,00
# ..              ...             ...             ...           ...
# 698         -3,2387         -0,1565         60,4614          0,00
# 699         -3,2512         -0,1373         76,9622          0,03
# 700         -3,2563          0,3513         60,3218          0,00
# 701         -3,3164         -0,5535         19,7093          0,01
# 702         -3,3464          0,2941         21,3893          0,10
#
#     Oberfläche [mm²] Mittlere Porosität [%] Porositätsabweichung [%]  \
# 0               0,08                   2,03                     0,02
# ...
