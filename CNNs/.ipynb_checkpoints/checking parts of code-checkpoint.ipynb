# %%
import os
import random

# %%
d = '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/dogs'

# %%
image_paths = []

# %%
for path in os.listdir(d):
    full_path = os.path.join(d,path)
    image_paths.append(full_path)

# %%
len(image_paths)
# Out:
# 2000

# %%
image_paths
# Out:
# ['/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00991.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00186.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00126.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00989.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00402.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00193.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00571.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00366.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00498.jpg',
# ...

# %%
random.seed(42)
random.shuffle(image_paths)

# %%
image_paths
# Out:
# ['/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00200.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/dogs/dogs_00236.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00899.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00713.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/dogs/dogs_00455.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/dogs/dogs_00882.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/dogs/dogs_00008.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/dogs/dogs_00439.jpg',
#  '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats/cats_00266.jpg',
# ...

# %%
os.listdir( '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats')
# Out:
# ['cats_00991.jpg',
#  'cats_00186.jpg',
#  'cats_00126.jpg',
#  'cats_00989.jpg',
#  'cats_00402.jpg',
#  'cats_00193.jpg',
#  'cats_00571.jpg',
#  'cats_00366.jpg',
#  'cats_00498.jpg',
#  'cats_00919.jpg',
#  'cats_00936.jpg',
#  'cats_00609.jpg',
#  'cats_00692.jpg',
#  'cats_00875.jpg',
#  'cats_00157.jpg',
#  'cats_00835.jpg',
#  'cats_00967.jpg',
#  'cats_00506.jpg',
#  'cats_00869.jpg',
#  'cats_00786.jpg',
#  'cats_00333.jpg',
#  'cats_00391.jpg',
#  'cats_00779.jpg',
#  'cats_00050.jpg',
#  'cats_00762.jpg',
#  'cats_00635.jpg',
#  'cats_00939.jpg',
#  'cats_00403.jpg',
#  'cats_00178.jpg',
#  'cats_00728.jpg',
#  'cats_00518.jpg',
#  'cats_00857.jpg',
#  'cats_00340.jpg',
#  'cats_00837.jpg',
#  'cats_00937.jpg',
#  'cats_00520.jpg',
#  'cats_00973.jpg',
#  'cats_00957.jpg',
#  'cats_00127.jpg',
#  'cats_00020.jpg',
#  'cats_00460.jpg',
#  'cats_00222.jpg',
#  'cats_00323.jpg',
#  'cats_00164.jpg',
#  'cats_00085.jpg',
#  'cats_00204.jpg',
#  'cats_00368.jpg',
# ...

# %%
d = '/home/jan/Documents/Examples/PyImageSearch_KerasTutorila/keras-tutorial/animals/cats'
for path in os.listdir(d):
    full_path = os.path.join(d, path)

# %%
sorted(list(paths.list_images()))

# %%
path1 = image_paths[-1]

# %%
labels = path1.split(os.path.sep)[-2]

# %%
label_list = []

# %%
for image_path in image_paths:
    label = image_path.split(os.path.sep)[-2]
    label_list.append(label)

# %%
label_list
# Out:
# ['cats',
#  'dogs',
#  'cats',
#  'cats',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'cats',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'cats',
#  'cats',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'cats',
#  'cats',
#  'cats',
#  'dogs',
#  'cats',
#  'cats',
#  'dogs',
#  'cats',
#  'cats',
#  'cats',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'cats',
#  'cats',
#  'dogs',
#  'cats',
#  'cats',
#  'dogs',
#  'dogs',
#  'cats',
#  'cats',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'cats',
#  'cats',
#  'dogs',
#  'cats',
#  'cats',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'dogs',
#  'dogs',
#  'cats',
#  'cats',
#  'dogs',
#  'dogs',
#  'cats',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'dogs',
#  'cats',
#  'dogs',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'dogs',
# ...
